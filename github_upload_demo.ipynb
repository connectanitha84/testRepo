# %% [markdown]
# <a href="https://colab.research.google.com/github/connectanitha84/testRepo/blob/main/github_upload_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello learning to upload to github")
# Out:
# hello learning to upload to github
